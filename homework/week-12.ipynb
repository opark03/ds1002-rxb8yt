# %% [markdown]
# <a href="https://colab.research.google.com/github/opark03/ds1002-rxb8yt/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
plt.pie(slices, labels=labels)
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
# when i type in the .hist, it gave me way more parameters to inlcude however it worked even though i did not include them. did i do somehting worng and if so why did it still work?
plt.hist(n)
plt.show()

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.scatter(x, y)

# %%
z = np.polyfit(x, y, 2)
p = np.poly1d(z)

# %%
# I am kinda confused if I did what the prompt was actually asking for here but because I am not sure what I am supposed to do with the data frame combination aspect
plt.scatter(x, y)
plt.plot(x, p(x))

# %%
df = pd.DataFrame({'x': x, 'y': y})
